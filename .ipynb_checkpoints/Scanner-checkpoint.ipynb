# %%
# Imports
from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import datetime
import time
yf.pdr_override()
from pathlib import Path

# %%
csv_path = Path("IBDStocks.csv")
ibd_df = pd.read_csv(csv_path)

# %%
ibd_df.head()
# Out:
#   Symbol
# 0   INMD
# 1   ASAN
# 2   ATKR
# 3   SWAV
# 4   LSPD

# %%
# Variables
#tickers = si.tickers_sp500()
tickers = ibd_df["Symbol"]
tickers = [item.replace(".", "-") for item in tickers] # Yahoo Finance uses dashes instead of dots
index_name = 'IBD' # S&P 500
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()
exportList = pd.DataFrame(columns=['Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])
returns_multiples = []

# %%
# Index Returns
index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_df['Percent Change'] = index_df['Adj Close'].pct_change()
index_return = (index_df['Percent Change'] + 1).cumprod()[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Find top 30% performing stocks (relative to the S&P 500)
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    df = pdr.get_data_yahoo(ticker, start_date, end_date)
    df.to_csv(f'{ticker}.csv')

    # Calculating returns relative to the market (returns multiple)
    df['Percent Change'] = df['Adj Close'].pct_change()
    stock_return = (df['Percent Change'] + 1).cumprod()[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against S&P 500: {returns_multiple}\n')
    time.sleep(1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker: INMD; Returns Multiple against S&P 500: 3.3
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ASAN; Returns Multiple against S&P 500: 3.5
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ATKR; Returns Multiple against S&P 500: 3.53
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SWAV; Returns Multiple against S&P 500: 2.98
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LSPD; Returns Multiple against S&P 500: 3.78
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: CELH; Returns Multiple against S&P 500: 3.95
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MRNA; Returns Multiple against S&P 500: 6.23
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: BILL; Returns Multiple against S&P 500: 3.2
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: UPST; Returns Multiple against S&P 500: 9.37
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TASK; Returns Multiple against S&P 500: 1.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NET; Returns Multiple against S&P 500: 3.42
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SE; Returns Multiple against S&P 500: 2.14
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: DOCS; Returns Multiple against S&P 500: 1.78
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ASML; Returns Multiple against S&P 500: 2.35
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WAL; Returns Multiple against S&P 500: 2.94
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GNRC; Returns Multiple against S&P 500: 2.33
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MDB; Returns Multiple against S&P 500: 2.26
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GLBE; Returns Multiple against S&P 500: 2.75
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: DLO; Returns Multiple against S&P 500: 1.87
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: RGEN; Returns Multiple against S&P 500: 1.91
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: PRFT; Returns Multiple against S&P 500: 2.6
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ZS; Returns Multiple against S&P 500: 2.01
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AVTR; Returns Multiple against S&P 500: 1.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: DDOG; Returns Multiple against S&P 500: 1.52
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SITM; Returns Multiple against S&P 500: 3.33
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: SPT; Returns Multiple against S&P 500: 3.62
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MNDY; Returns Multiple against S&P 500: 2.05
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WST; Returns Multiple against S&P 500: 1.55
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: NVDA; Returns Multiple against S&P 500: 1.7
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: BX; Returns Multiple against S&P 500: 2.51
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: HUBS; Returns Multiple against S&P 500: 2.36
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ZI; Returns Multiple against S&P 500: 1.97
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JBL; Returns Multiple against S&P 500: 1.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IT; Returns Multiple against S&P 500: 2.29
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ALGN; Returns Multiple against S&P 500: 2.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: GOOGL; Returns Multiple against S&P 500: 1.84
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MPWR; Returns Multiple against S&P 500: 1.89
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: ARES; Returns Multiple against S&P 500: 2.0
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: IIPR; Returns Multiple against S&P 500: 1.86
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: MATX; Returns Multiple against S&P 500: 2.19
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: KLIC; Returns Multiple against S&P 500: 3.12
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: BLDR; Returns Multiple against S&P 500: 1.63
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: CROX; Returns Multiple against S&P 500: 3.21
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: JEF; Returns Multiple against S&P 500: 2.19
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: WSM; Returns Multiple against S&P 500: 1.93
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: AXNX; Returns Multiple against S&P 500: 1.72
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: RCII; Returns Multiple against S&P 500: 2.11
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: TPX; Returns Multiple against S&P 500: 2.03
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: CCS; Returns Multiple against S&P 500: 1.71
#
# [*********************100%***********************]  1 of 1 completed
# Ticker: LULU; Returns Multiple against S&P 500: 1.34

# %%
# Creating dataframe of only top 30%
rs_df = pd.DataFrame(list(zip(tickers, returns_multiples)), columns=['Ticker', 'Returns_multiple'])
rs_df['RS_Rating'] = rs_df.Returns_multiple.rank(pct=True) * 100
rs_df = rs_df[rs_df.RS_Rating >= rs_df.RS_Rating.quantile(.50)]

# %%
# Checking Minervini conditions of top 30% of stocks in given list
rs_stocks = rs_df['Ticker']
for stock in rs_stocks:    
    try:
        df = pd.read_csv(f'{stock}.csv', index_col=0)
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"][-260:]), 2)
        high_of_52week = round(max(df["High"][-260:]), 2)
        RS_Rating = round(rs_df[rs_df['Ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price > 150 SMA and > 200 SMA
        condition_1 = currentClose > moving_average_150 > moving_average_200
        
        # Condition 2: 150 SMA and > 200 SMA
        condition_2 = moving_average_150 > moving_average_200

        # Condition 3: 200 SMA trending up for at least 1 month
        condition_3 = moving_average_200 > moving_average_200_20
        
        # Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
           
        # Condition 5: Current Price > 50 SMA
        condition_5 = currentClose > moving_average_50
           
        # Condition 6: Current Price is at least 30% above 52 week low
        condition_6 = currentClose >= (1.3*low_of_52week)
           
        # Condition 7: Current Price is within 25% of 52 week high
        condition_7 = currentClose >= (.75*high_of_52week)
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7):
            exportList = exportList.append({'Stock': stock, "RS_Rating": RS_Rating ,"50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")
# Out:
# INMD made the Minervini requirements
# ASAN made the Minervini requirements
# ATKR made the Minervini requirements
# SWAV made the Minervini requirements
# LSPD made the Minervini requirements
# CELH made the Minervini requirements
# MRNA made the Minervini requirements
# BILL made the Minervini requirements
# NET made the Minervini requirements
# ASML made the Minervini requirements
# WAL made the Minervini requirements
# GNRC made the Minervini requirements
# PRFT made the Minervini requirements
# SITM made the Minervini requirements
# SPT made the Minervini requirements
# BX made the Minervini requirements
# HUBS made the Minervini requirements
# IT made the Minervini requirements
# MATX made the Minervini requirements
# KLIC made the Minervini requirements
# CROX made the Minervini requirements
# JEF made the Minervini requirements

# %%
exportList = exportList.sort_values(by='RS_Rating', ascending=False)
print('\n', exportList)
writer = ExcelWriter("ScreenOutput.xlsx")
exportList.to_excel(writer, "Sheet1")
writer.save()
# Out:
#     Stock RS_Rating  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  \
# 6   MRNA        98     357.92      231.47      208.47        63.64
# 5   CELH        96      73.14       63.49       59.87        18.71
# 4   LSPD        94      94.84       77.82       74.68        28.29
# 14   SPT        92     102.96       79.54       73.40        31.64
# 2   ATKR        90      81.50       76.08       68.35        20.42
# 1   ASAN        88      75.57       49.89       45.47        20.57
# 8    NET        86     118.01       92.78       89.52        34.53
# 13  SITM        84     168.86      126.24      123.66        63.00
# 0   INMD        82     114.76       91.34       81.36        33.92
# 20  CROX        80     133.54      105.56       96.10        40.12
# 7   BILL        78     219.62      178.66      167.81        82.19
# 19  KLIC        76      61.47       54.83       49.77        21.86
# 3   SWAV        74     190.61      161.71      148.87        64.24
# 10   WAL        72      96.09       96.05       87.76        30.34
# 12  PRFT        68      99.35       77.49       70.64        37.42
# 15    BX        66     113.55       92.34       84.92        49.26
# 16  HUBS        64     631.97      547.23      508.39       264.06
# 9   ASML        62     773.65      674.99      630.94       351.09
# 11  GNRC        60     427.55      363.00      331.93       173.80
# 17    IT        58     284.76      232.32      213.86       115.86
# 18  MATX        53      71.91       68.78       66.60        36.78
# 21   JEF        53      34.41       32.24       30.17        17.03
#
#     52 week High
# 6         497.49
# 5          93.49
# 4         128.13
# 14        132.69
# 2          98.00
# 1         107.10
# 8         132.09
# 13        232.27
# 0         142.18
# 20        147.76
# 7         301.99
# 19         75.29
# 3         237.76
# 10        109.84
# 12        122.78
# 15        130.89
# 16        715.29
# 9         875.36
# 11        466.92
# 17        318.30
# 18         87.99
# 21         37.85
