# %%
# Imports
from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import datetime
import time
yf.pdr_override()
from pathlib import Path
import numpy as np

# %%
# scan a list of stocks from a csv file of Investors Business Daily recommendations
csv_path = Path("IBDStocks.csv")
ibd_df = pd.read_csv(csv_path)

# %%
ibd_df.tail()
# Out:
#    Symbol
# 63   TSLA
# 64     FB
# 65   AAPL
# 66    LOW
# 67   AMZN

# %%
# Variables, tickers from the IBD list
#tickers = si.tickers_sp500()
tickers = ibd_df["Symbol"]
tickers = [item.replace(".", "-") for item in tickers] # Yahoo Finance uses dashes instead of dots
index_name = 'IBD' # S&P 500
exportList = pd.DataFrame(columns=['Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])
returns_multiples = []

# %%
#Index from the list above Returns
index_df = pdr.get_data_yahoo(index_name)
index_df['Percent Change'] = index_df['Adj Close'].pct_change()
index_return = (index_df['Percent Change'] + 1).cumprod()[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# parameter setup (default values in the original indicator)
#These are the constants to be used for the moving averages, the bollinger bands and the keltner channels
#ultimately these will be needed for the squeeze and other calculations
length = 20
mult = 2
length_KC = 21
mult_KC = 2

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df = stock.history(period="3y", interval='1d')
    df.to_csv(f'{ticker}.csv')    
    m_avg = df['Close'].ewm(span=length).mean()
    df['Moving average'] = m_avg
    # standard deviation
    m_std = df['Close'].rolling(window=length).std()
    # upper Bollinger Bands
    df['upper_BB'] = m_avg + mult * m_std
    # lower Bollinger Bands 
    df['lower_BB'] = m_avg - mult * m_std
    # calculate Keltner Channel which is a measure of the average true range.  In this case the channels are set to twice the average true range
    # first we need to calculate True Range
    df['tr0'] = abs(df["High"] - df["Low"])
    df['tr1'] = abs(df["High"] - df["Close"].shift())
    df['tr2'] = abs(df["Low"] - df["Close"].shift())
    df['tr'] = df[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma = df['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df['upper_KC'] = m_avg + range_ma * mult_KC
    # lower Keltner Channel
    df['lower_KC'] = m_avg - range_ma * mult_KC
    
    df['squeeze_on'] = (df['lower_BB'] > df['lower_KC']) & (df['upper_BB'] < df['upper_KC'])
    df['squeeze_off'] = (df['lower_BB'] < df['lower_KC']) & (df['upper_BB'] > df['upper_KC'])
    
    highest = df['High'].rolling(window = length_KC).max()
    lowest = df['Low'].rolling(window = length_KC).min()
    m1 = (highest + lowest) / 2
    df['value'] = (df['Close'] - (m1 + m_avg)/2)
    fit_y = np.array(range(0,length_KC))
    df['value'] = df['value'].rolling(window = length_KC).apply(lambda x : np.polyfit(fit_y, x, 1)[0] * (length_KC-1) +
    np.polyfit(fit_y, x, 1)[1], raw=True)

    df[['squeeze_on', 'squeeze_off']] = (df[['squeeze_on', 'squeeze_off']] == True).astype(float)

    df["pct_change"] = df['Close'].pct_change()*100

    conditions =  [
        (df['pct_change'] > 0),
        (df['pct_change'] < 0)
    ]

    label = [1, 0]
    df['profitable?'] = np.select(conditions, label) 
    
    # entry point for long position:
    # 1. black cross becomes gray (the squeeze is released)
    long_cond1 = (df['squeeze_off'][-2] == 0) | (df['squeeze_off'][-1] == 1) 
    # 2. bar value is positive => the bar is light green
    long_cond2 = df['value'][-1] > 0

    enter_long = long_cond1 and long_cond2
    # entry point for short position:
    # 1. black cross becomes gray (the squeeze is released)
    short_cond1 = (df['squeeze_off'][-2] == 0) | (df['squeeze_off'][-1] == 1) 
    # 2. bar value is negative => the bar is light red 
    short_cond2 = df['value'][-1] < 0
    enter_short = short_cond1 and short_cond2

    colors = []
    for ind, val in enumerate(df['value']):
        if val >= 0:
            color = 'blue'
            if val > df['value'][ind-1]:
                color = 'cyan'
                    
        else:
            color = 'yellow'
            if val < df['value'][ind-1]:
                color='red'        
        colors.append(color)    
    df['colors'] = colors
    color_value = df['colors'][-1]
    squeeze_value = df['squeeze_on'][-1]
    
    print (f'Ticker: {ticker}; Squeeze_scan\n {squeeze_value},{color_value}')
    time.sleep(1)
# Out:
# Ticker: INMD; Squeeze_scan
#  1.0,blue
# Ticker: ASAN; Squeeze_scan
#  1.0,cyan
# Ticker: ATKR; Squeeze_scan
#  0.0,cyan
# Ticker: SWAV; Squeeze_scan
#  0.0,red
# Ticker: LSPD; Squeeze_scan
#  0.0,red
# Ticker: CELH; Squeeze_scan
#  0.0,red
# Ticker: MRNA; Squeeze_scan
#  0.0,yellow
# Ticker: BILL; Squeeze_scan
#  0.0,blue
# Ticker: UPST; Squeeze_scan
#  0.0,red
# Ticker: TASK; Squeeze_scan
#  1.0,red
# Ticker: NET; Squeeze_scan
#  0.0,blue
# Ticker: SE; Squeeze_scan
#  1.0,red
# Ticker: DOCS; Squeeze_scan
#  1.0,blue
# Ticker: ASML; Squeeze_scan
#  0.0,blue
# Ticker: WAL; Squeeze_scan
#  1.0,red
# Ticker: GNRC; Squeeze_scan
#  0.0,red
# Ticker: MDB; Squeeze_scan
#  0.0,blue
# Ticker: GLBE; Squeeze_scan
#  0.0,cyan
# Ticker: DLO; Squeeze_scan
#  0.0,red
# Ticker: RGEN; Squeeze_scan
#  0.0,yellow
# Ticker: PRFT; Squeeze_scan
#  0.0,blue
# Ticker: ZS; Squeeze_scan
#  0.0,cyan
# Ticker: AVTR; Squeeze_scan
#  1.0,cyan
# Ticker: DDOG; Squeeze_scan
#  0.0,blue
# Ticker: SITM; Squeeze_scan
#  0.0,cyan
# Ticker: SPT; Squeeze_scan
#  1.0,blue
# Ticker: MNDY; Squeeze_scan
#  1.0,red
# Ticker: WST; Squeeze_scan
#  0.0,cyan
# Ticker: NVDA; Squeeze_scan
#  0.0,cyan
# Ticker: BX; Squeeze_scan
#  1.0,blue
# Ticker: HUBS; Squeeze_scan
#  1.0,blue
# Ticker: ZI; Squeeze_scan
#  0.0,cyan
# Ticker: JBL; Squeeze_scan
#  0.0,blue
# Ticker: IT; Squeeze_scan
#  1.0,red
# Ticker: ALGN; Squeeze_scan
#  0.0,blue
# Ticker: GOOGL; Squeeze_scan
#  0.0,blue
# Ticker: MPWR; Squeeze_scan
#  0.0,blue
# Ticker: ARES; Squeeze_scan
#  1.0,blue
# Ticker: IIPR; Squeeze_scan
#  0.0,blue
# Ticker: MATX; Squeeze_scan
#  0.0,blue
# Ticker: KLIC; Squeeze_scan
#  1.0,blue
# Ticker: BLDR; Squeeze_scan
#  0.0,cyan
# Ticker: CROX; Squeeze_scan
#  0.0,blue
# Ticker: JEF; Squeeze_scan
#  0.0,red
# Ticker: WSM; Squeeze_scan
#  0.0,cyan
# Ticker: AXNX; Squeeze_scan
#  0.0,red
# Ticker: RCII; Squeeze_scan
#  0.0,yellow
# Ticker: TPX; Squeeze_scan
#  1.0,yellow
# Ticker: CCS; Squeeze_scan
#  0.0,blue
# Ticker: LULU; Squeeze_scan
#  0.0,blue
# Ticker: NFLX; Squeeze_scan
#  1.0,blue
# Ticker: MA; Squeeze_scan
#  0.0,blue
# Ticker: ^DJI; Squeeze_scan
#  1.0,blue
# Ticker: QQQ; Squeeze_scan
#  0.0,cyan
# Ticker: SPY; Squeeze_scan
#  0.0,blue
# Ticker: ES=F; Squeeze_scan
#  0.0,blue
# Ticker: YM=F; Squeeze_scan
#  1.0,red
# Ticker: NQ=F; Squeeze_scan
#  0.0,blue
# Ticker: ROKU; Squeeze_scan
#  0.0,red
# Ticker: WFC; Squeeze_scan
#  1.0,red
# Ticker: JD; Squeeze_scan
#  0.0,cyan
# Ticker: AMC; Squeeze_scan
#  0.0,cyan
# Ticker: BA; Squeeze_scan
#  0.0,blue
# Ticker: TSLA; Squeeze_scan
#  0.0,blue
# Ticker: FB; Squeeze_scan
#  0.0,cyan
# Ticker: AAPL; Squeeze_scan
#  0.0,cyan
# Ticker: LOW; Squeeze_scan
#  0.0,cyan
# Ticker: AMZN; Squeeze_scan
#  0.0,cyan

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df = stock.history(period="3y", interval='1d')
    df.to_csv(f'{ticker}.csv')
    #Stacked Moving averages, exponentially weighted.  Focusing on Fibonacci numbers here with 8, 21, 34, 55 and 89 day moving averages
    m_avg_08 = df['Close'].ewm(span=8).mean()
    m_avg_21 = df['Close'].ewm(span=21).mean()
    m_avg_34 = df['Close'].ewm(span=34).mean()
    m_avg_55 = df['Close'].ewm(span=55).mean()
    m_avg_89 = df['Close'].ewm(span=89).mean()

    df['m_avg_08'] = m_avg_08
    df['m_avg_21'] = m_avg_21
    df['m_avg_34'] = m_avg_34
    df['m_avg_55'] = m_avg_55
    df['m_avg_89'] = m_avg_89
    
    df['tr0'] = abs(df["High"] - df["Low"])
    df['tr1'] = abs(df["High"] - df["Close"].shift())
    df['tr2'] = abs(df["Low"] - df["Close"].shift())
    df['tr'] = df[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma = df['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df['upper_KC'] = m_avg + range_ma * mult_KC
    # lower Keltner Channel
    df['lower_KC'] = m_avg - range_ma * mult_KC
    
    plus_dm = df["High"].diff()
    minus_dm = df["Low"].diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    #plus_di and minus di show the direction of the trend, if plus_di > minus_di the trend is positive
    #if minus_di > plus_di the trend is negative
    df['atr'] = df['tr'].ewm(span=14).mean()
    df['plus_di'] = 100 * (plus_dm.ewm(alpha = 1/14).mean() / df['atr'])
    df['minus_di'] = abs(100 * (minus_dm.ewm(alpha = 1/14).mean() / df['atr']))
    dx = (abs(df['plus_di'] - df['minus_di']) / abs(df['plus_di'] + df['minus_di'])) * 100
    adx = ((dx.shift(1) * (14 - 1)) + dx) / 14
    df['adx'] = adx.ewm(alpha = 1/14).mean() #ADX>20 is trending ADX<20 not trending
    
    df['ADX_trend'] = 20
    
    
    
    if (df['m_avg_08'][-1] > df['m_avg_21'][-1] > df['m_avg_34'][-1] > df['m_avg_55'][-1] > df['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Stacked EMA\n is in the positive direction')
    elif (df['m_avg_08'][-1] < df['m_avg_21'][-1] < df['m_avg_34'][-1] < df['m_avg_55'][-1] < df['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Stacked EMA\n is in the negative direction')
    else:
        print (f'Ticker: {ticker}; Stacked EMA\n is neutral')
        
    if (df['adx'][-1] > df['ADX_trend'][-1]) and (df['plus_di'][-1] > df['minus_di'][-1]):
        print (f'Ticker: {ticker}; Directional trend is positive')
    elif (df['adx'][-1] > df['ADX_trend'][-1]) and (df['plus_di'][-1] < df['minus_di'][-1]):
        print (f'Ticker: {ticker}; Directional trend is negative')
    elif (df['adx'][-1] < df['ADX_trend'][-1]):
        print (f'Ticker: {ticker}; Directional trend is neutral or sideways')
    time.sleep(1)
# Out:
# Ticker: INMD; Stacked EMA
#  is in the positive direction
# Ticker: INMD; Directional trend is neutral or sideways
# Ticker: ASAN; Stacked EMA
#  is in the positive direction
# Ticker: ASAN; Directional trend is positive
# Ticker: ATKR; Stacked EMA
#  is in the positive direction
# Ticker: ATKR; Directional trend is positive
# Ticker: SWAV; Stacked EMA
#  is neutral
# Ticker: SWAV; Directional trend is neutral or sideways
# Ticker: LSPD; Stacked EMA
#  is in the negative direction
# Ticker: LSPD; Directional trend is negative
# Ticker: CELH; Stacked EMA
#  is neutral
# Ticker: CELH; Directional trend is negative
# Ticker: MRNA; Stacked EMA
#  is in the negative direction
# Ticker: MRNA; Directional trend is negative
# Ticker: BILL; Stacked EMA
#  is in the positive direction
# Ticker: BILL; Directional trend is positive
# Ticker: UPST; Stacked EMA
#  is neutral
# Ticker: UPST; Directional trend is negative
# Ticker: TASK; Stacked EMA
#  is neutral
# Ticker: TASK; Directional trend is neutral or sideways
# Ticker: NET; Stacked EMA
#  is in the positive direction
# Ticker: NET; Directional trend is positive
# Ticker: SE; Stacked EMA
#  is neutral
# Ticker: SE; Directional trend is neutral or sideways
# Ticker: DOCS; Stacked EMA
#  is in the negative direction
# Ticker: DOCS; Directional trend is neutral or sideways
# Ticker: ASML; Stacked EMA
#  is in the positive direction
# Ticker: ASML; Directional trend is neutral or sideways
# Ticker: WAL; Stacked EMA
#  is in the positive direction
# Ticker: WAL; Directional trend is negative
# Ticker: GNRC; Stacked EMA
#  is neutral
# Ticker: GNRC; Directional trend is neutral or sideways
# Ticker: MDB; Stacked EMA
#  is in the positive direction
# Ticker: MDB; Directional trend is positive
# Ticker: GLBE; Stacked EMA
#  is neutral
# Ticker: GLBE; Directional trend is positive
# Ticker: DLO; Stacked EMA
#  is in the negative direction
# Ticker: DLO; Directional trend is negative
# Ticker: RGEN; Stacked EMA
#  is neutral
# Ticker: RGEN; Directional trend is negative
# Ticker: PRFT; Stacked EMA
#  is in the positive direction
# Ticker: PRFT; Directional trend is positive
# Ticker: ZS; Stacked EMA
#  is in the positive direction
# Ticker: ZS; Directional trend is positive
# Ticker: AVTR; Stacked EMA
#  is neutral
# Ticker: AVTR; Directional trend is neutral or sideways
# Ticker: DDOG; Stacked EMA
#  is in the positive direction
# Ticker: DDOG; Directional trend is positive
# Ticker: SITM; Stacked EMA
#  is in the positive direction
# Ticker: SITM; Directional trend is positive
# Ticker: SPT; Stacked EMA
#  is in the positive direction
# Ticker: SPT; Directional trend is neutral or sideways
# Ticker: MNDY; Stacked EMA
#  is in the positive direction
# Ticker: MNDY; Directional trend is positive
# Ticker: WST; Stacked EMA
#  is in the positive direction
# Ticker: WST; Directional trend is neutral or sideways
# Ticker: NVDA; Stacked EMA
#  is in the positive direction
# Ticker: NVDA; Directional trend is positive
# Ticker: BX; Stacked EMA
#  is in the positive direction
# Ticker: BX; Directional trend is positive
# Ticker: HUBS; Stacked EMA
#  is in the positive direction
# Ticker: HUBS; Directional trend is positive
# Ticker: ZI; Stacked EMA
#  is in the positive direction
# Ticker: ZI; Directional trend is positive
# Ticker: JBL; Stacked EMA
#  is in the positive direction
# Ticker: JBL; Directional trend is neutral or sideways
# Ticker: IT; Stacked EMA
#  is in the positive direction
# Ticker: IT; Directional trend is positive
# Ticker: ALGN; Stacked EMA
#  is in the positive direction
# Ticker: ALGN; Directional trend is positive
# Ticker: GOOGL; Stacked EMA
#  is in the positive direction
# Ticker: GOOGL; Directional trend is neutral or sideways
# Ticker: MPWR; Stacked EMA
#  is in the positive direction
# Ticker: MPWR; Directional trend is positive
# Ticker: ARES; Stacked EMA
#  is in the positive direction
# Ticker: ARES; Directional trend is positive
# Ticker: IIPR; Stacked EMA
#  is in the positive direction
# Ticker: IIPR; Directional trend is positive
# Ticker: MATX; Stacked EMA
#  is in the positive direction
# Ticker: MATX; Directional trend is positive
# Ticker: KLIC; Stacked EMA
#  is neutral
# Ticker: KLIC; Directional trend is neutral or sideways
# Ticker: BLDR; Stacked EMA
#  is in the positive direction
# Ticker: BLDR; Directional trend is positive
# Ticker: CROX; Stacked EMA
#  is in the positive direction
# Ticker: CROX; Directional trend is positive
# Ticker: JEF; Stacked EMA
#  is neutral
# Ticker: JEF; Directional trend is negative
# Ticker: WSM; Stacked EMA
#  is in the positive direction
# Ticker: WSM; Directional trend is positive
# Ticker: AXNX; Stacked EMA
#  is neutral
# Ticker: AXNX; Directional trend is negative
# Ticker: RCII; Stacked EMA
#  is in the negative direction
# Ticker: RCII; Directional trend is negative
# Ticker: TPX; Stacked EMA
#  is neutral
# Ticker: TPX; Directional trend is neutral or sideways
# Ticker: CCS; Stacked EMA
#  is in the positive direction
# Ticker: CCS; Directional trend is positive
# Ticker: LULU; Stacked EMA
#  is in the positive direction
# Ticker: LULU; Directional trend is positive
# Ticker: NFLX; Stacked EMA
#  is in the positive direction
# Ticker: NFLX; Directional trend is positive
# Ticker: MA; Stacked EMA
#  is neutral
# Ticker: MA; Directional trend is neutral or sideways
# Ticker: ^DJI; Stacked EMA
#  is in the positive direction
# Ticker: ^DJI; Directional trend is negative
# Ticker: QQQ; Stacked EMA
#  is in the positive direction
# Ticker: QQQ; Directional trend is positive
# Ticker: SPY; Stacked EMA
#  is in the positive direction
# Ticker: SPY; Directional trend is positive
# Ticker: ES=F; Stacked EMA
#  is in the positive direction
# Ticker: ES=F; Directional trend is positive
# Ticker: YM=F; Stacked EMA
#  is in the positive direction
# Ticker: YM=F; Directional trend is negative
# Ticker: NQ=F; Stacked EMA
#  is in the positive direction
# Ticker: NQ=F; Directional trend is positive
# Ticker: ROKU; Stacked EMA
#  is in the negative direction
# Ticker: ROKU; Directional trend is negative
# Ticker: WFC; Stacked EMA
#  is in the positive direction
# Ticker: WFC; Directional trend is neutral or sideways
# Ticker: JD; Stacked EMA
#  is in the positive direction
# Ticker: JD; Directional trend is neutral or sideways
# Ticker: AMC; Stacked EMA
#  is in the positive direction
# Ticker: AMC; Directional trend is positive
# Ticker: BA; Stacked EMA
#  is neutral
# Ticker: BA; Directional trend is negative
# Ticker: TSLA; Stacked EMA
#  is in the positive direction
# Ticker: TSLA; Directional trend is positive
# Ticker: FB; Stacked EMA
#  is neutral
# Ticker: FB; Directional trend is neutral or sideways
# Ticker: AAPL; Stacked EMA
#  is in the positive direction
# Ticker: AAPL; Directional trend is neutral or sideways
# Ticker: LOW; Stacked EMA
#  is in the positive direction
# Ticker: LOW; Directional trend is positive
# Ticker: AMZN; Stacked EMA
#  is in the positive direction
# Ticker: AMZN; Directional trend is positive

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df_wk = stock.history(period="5y", interval='1wk')
    df_wk.to_csv(f'{ticker}_wk.csv')    
    m_avg_wk = df_wk['Close'].ewm(span=length).mean()
    df_wk['Moving average'] = m_avg_wk
    # standard deviation
    m_std_wk = df_wk['Close'].rolling(window=length).std()
    # upper Bollinger Bands
    df_wk['upper_BB'] = m_avg_wk + mult * m_std_wk
    # lower Bollinger Bands 
    df_wk['lower_BB'] = m_avg_wk - mult * m_std_wk
    # calculate Keltner Channel which is a measure of the average true range.  In this case the channels are set to twice the average true range
    # first we need to calculate True Range
    df_wk['tr0'] = abs(df_wk["High"] - df_wk["Low"])
    df_wk['tr1'] = abs(df_wk["High"] - df_wk["Close"].shift())
    df_wk['tr2'] = abs(df_wk["Low"] - df_wk["Close"].shift())
    df_wk['tr'] = df_wk[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma_wk = df_wk['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df_wk['upper_KC'] = m_avg_wk + range_ma_wk * mult_KC
    # lower Keltner Channel
    df_wk['lower_KC'] = m_avg_wk - range_ma_wk * mult_KC
    
    df_wk['squeeze_on'] = (df_wk['lower_BB'] > df_wk['lower_KC']) & (df_wk['upper_BB'] < df_wk['upper_KC'])
    df_wk['squeeze_off'] = (df_wk['lower_BB'] < df_wk['lower_KC']) & (df_wk['upper_BB'] > df_wk['upper_KC'])
    
    highest_wk = df_wk['High'].rolling(window = length_KC).max()
    lowest_wk = df_wk['Low'].rolling(window = length_KC).min()
    m1_wk = (highest_wk + lowest_wk) / 2
    df_wk['value'] = (df_wk['Close'] - (m1_wk + m_avg_wk)/2)
    fit_y_wk = np.array(range(0,length_KC))
    df_wk['value'] = df_wk['value'].rolling(window = length_KC).apply(lambda x : np.polyfit(fit_y_wk, x, 1)[0] * (length_KC-1) +
    np.polyfit(fit_y_wk, x, 1)[1], raw=True)

    df_wk[['squeeze_on', 'squeeze_off']] = (df_wk[['squeeze_on', 'squeeze_off']] == True).astype(float)

    df_wk["pct_change"] = df_wk['Close'].pct_change()*100

    conditions_wk =  [
        (df_wk['pct_change'] > 0),
        (df_wk['pct_change'] < 0)
    ]

    label = [1, 0]
    df_wk['profitable?'] = np.select(conditions_wk, label) 
    
    # entry point for long position:
    # 1. black cross becomes gray (the squeeze is released)
    long_cond1_wk = (df_wk['squeeze_off'][-2] == 0) | (df_wk['squeeze_off'][-1] == 1) 
    # 2. bar value is positive => the bar is light green
    long_cond2_wk = df_wk['value'][-1] > 0

    enter_long_wk = long_cond1_wk and long_cond2_wk
    # entry point for short position:
    # 1. black cross becomes gray (the squeeze is released)
    short_cond1_wk = (df_wk['squeeze_off'][-2] == 0) | (df_wk['squeeze_off'][-1] == 1) 
    # 2. bar value is negative => the bar is light red 
    short_cond2_wk = df_wk['value'][-1] < 0
    enter_short_wk = short_cond1_wk and short_cond2_wk

    colors = []
    for ind, val in enumerate(df_wk['value']):
        if val >= 0:
            color = 'blue'
            if val > df_wk['value'][ind-1]:
                color = 'cyan'
                    
        else:
            color = 'yellow'
            if val < df_wk['value'][ind-1]:
                color='red'        
        colors.append(color)    
    df_wk['colors'] = colors
    color_value_wk = df_wk['colors'][-1]
    squeeze_value_wk = df_wk['squeeze_on'][-1]
    
    print (f'Ticker: {ticker}; weekly squeeze_scan\n {squeeze_value_wk},{color_value_wk}')
    time.sleep(1)
# Out:
# Ticker: INMD; weekly squeeze_scan
#  0.0,yellow
# Ticker: ASAN; weekly squeeze_scan
#  0.0,blue
# Ticker: ATKR; weekly squeeze_scan
#  0.0,cyan
# Ticker: SWAV; weekly squeeze_scan
#  1.0,blue
# Ticker: LSPD; weekly squeeze_scan
#  0.0,red
# Ticker: CELH; weekly squeeze_scan
#  0.0,blue
# Ticker: MRNA; weekly squeeze_scan
#  0.0,red
# Ticker: BILL; weekly squeeze_scan
#  0.0,blue
# Ticker: UPST; weekly squeeze_scan
#  0.0,blue
# Ticker: TASK; weekly squeeze_scan
#  0.0,yellow
# Ticker: NET; weekly squeeze_scan
#  0.0,cyan
# Ticker: SE; weekly squeeze_scan
#  1.0,blue
# Ticker: DOCS; weekly squeeze_scan
#  0.0,yellow
# Ticker: ASML; weekly squeeze_scan
#  0.0,yellow
# Ticker: WAL; weekly squeeze_scan
#  0.0,yellow
# Ticker: GNRC; weekly squeeze_scan
#  1.0,blue
# Ticker: MDB; weekly squeeze_scan
#  0.0,cyan
# Ticker: GLBE; weekly squeeze_scan
#  1.0,yellow
# Ticker: DLO; weekly squeeze_scan
#  0.0,yellow
# Ticker: RGEN; weekly squeeze_scan
#  0.0,blue
# Ticker: PRFT; weekly squeeze_scan
#  0.0,cyan
# Ticker: ZS; weekly squeeze_scan
#  0.0,cyan
# Ticker: AVTR; weekly squeeze_scan
#  1.0,blue
# Ticker: DDOG; weekly squeeze_scan
#  0.0,cyan
# Ticker: SITM; weekly squeeze_scan
#  0.0,cyan
# Ticker: SPT; weekly squeeze_scan
#  0.0,blue
# Ticker: MNDY; weekly squeeze_scan
#  0.0,yellow
# Ticker: WST; weekly squeeze_scan
#  0.0,yellow
# Ticker: NVDA; weekly squeeze_scan
#  0.0,yellow
# Ticker: BX; weekly squeeze_scan
#  0.0,yellow
# Ticker: HUBS; weekly squeeze_scan
#  0.0,blue
# Ticker: ZI; weekly squeeze_scan
#  0.0,cyan
# Ticker: JBL; weekly squeeze_scan
#  0.0,yellow
# Ticker: IT; weekly squeeze_scan
#  0.0,blue
# Ticker: ALGN; weekly squeeze_scan
#  0.0,red
# Ticker: GOOGL; weekly squeeze_scan
#  0.0,blue
# Ticker: MPWR; weekly squeeze_scan
#  0.0,yellow
# Ticker: ARES; weekly squeeze_scan
#  0.0,yellow
# Ticker: IIPR; weekly squeeze_scan
#  0.0,yellow
# Ticker: MATX; weekly squeeze_scan
#  0.0,yellow
# Ticker: KLIC; weekly squeeze_scan
#  0.0,yellow
# Ticker: BLDR; weekly squeeze_scan
#  0.0,cyan
# Ticker: CROX; weekly squeeze_scan
#  0.0,cyan
# Ticker: JEF; weekly squeeze_scan
#  0.0,yellow
# Ticker: WSM; weekly squeeze_scan
#  0.0,yellow
# Ticker: AXNX; weekly squeeze_scan
#  1.0,red
# Ticker: RCII; weekly squeeze_scan
#  0.0,red
# Ticker: TPX; weekly squeeze_scan
#  0.0,yellow
# Ticker: CCS; weekly squeeze_scan
#  0.0,yellow
# Ticker: LULU; weekly squeeze_scan
#  0.0,cyan
# Ticker: NFLX; weekly squeeze_scan
#  0.0,cyan
# Ticker: MA; weekly squeeze_scan
#  0.0,yellow
# Ticker: ^DJI; weekly squeeze_scan
#  1.0,blue
# Ticker: QQQ; weekly squeeze_scan
#  0.0,cyan
# Ticker: SPY; weekly squeeze_scan
#  0.0,yellow
# Ticker: ES=F; weekly squeeze_scan
#  0.0,cyan
# Ticker: YM=F; weekly squeeze_scan
#  1.0,blue
# Ticker: NQ=F; weekly squeeze_scan
#  0.0,cyan
# Ticker: ROKU; weekly squeeze_scan
#  0.0,red
# Ticker: WFC; weekly squeeze_scan
#  0.0,yellow
# Ticker: JD; weekly squeeze_scan
#  0.0,cyan
# Ticker: AMC; weekly squeeze_scan
#  1.0,yellow
# Ticker: BA; weekly squeeze_scan
#  1.0,yellow
# Ticker: TSLA; weekly squeeze_scan
#  0.0,cyan
# Ticker: FB; weekly squeeze_scan
#  1.0,yellow
# Ticker: AAPL; weekly squeeze_scan
#  0.0,yellow
# Ticker: LOW; weekly squeeze_scan
#  0.0,yellow
# Ticker: AMZN; weekly squeeze_scan
#  1.0,cyan

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df_wk = stock.history(period="5y", interval='1wk')
    df_wk.to_csv(f'{ticker}_wk.csv')
    #Stacked Moving averages, exponentially weighted.  Focusing on Fibonacci numbers here with 8, 21, 34, 55 and 89 day moving averages
    m_avg_08_wk = df_wk['Close'].ewm(span=8).mean()
    m_avg_21_wk = df_wk['Close'].ewm(span=21).mean()
    m_avg_34_wk = df_wk['Close'].ewm(span=34).mean()
    m_avg_55_wk = df_wk['Close'].ewm(span=55).mean()
    m_avg_89_wk = df_wk['Close'].ewm(span=89).mean()

    df_wk['m_avg_08'] = m_avg_08_wk
    df_wk['m_avg_21'] = m_avg_21_wk
    df_wk['m_avg_34'] = m_avg_34_wk
    df_wk['m_avg_55'] = m_avg_55_wk
    df_wk['m_avg_89'] = m_avg_89_wk
    
    df_wk['tr0'] = abs(df_wk["High"] - df_wk["Low"])
    df_wk['tr1'] = abs(df_wk["High"] - df_wk["Close"].shift())
    df_wk['tr2'] = abs(df_wk["Low"] - df_wk["Close"].shift())
    df_wk['tr'] = df_wk[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma = df_wk['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df_wk['upper_KC'] = m_avg_wk + range_ma * mult_KC
    # lower Keltner Channel
    df_wk['lower_KC'] = m_avg_wk - range_ma * mult_KC
    
    plus_dm = df_wk["High"].diff()
    minus_dm = df_wk["Low"].diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    #plus_di and minus di show the direction of the trend, if plus_di > minus_di the trend is positive
    #if minus_di > plus_di the trend is negative
    df_wk['atr'] = df_wk['tr'].ewm(span=14).mean()
    df_wk['plus_di'] = 100 * (plus_dm.ewm(alpha = 1/14).mean() / df_wk['atr'])
    df_wk['minus_di'] = abs(100 * (minus_dm.ewm(alpha = 1/14).mean() / df_wk['atr']))
    dx_wk = (abs(df_wk['plus_di'] - df_wk['minus_di']) / abs(df_wk['plus_di'] + df_wk['minus_di'])) * 100
    adx_wk = ((dx_wk.shift(1) * (14 - 1)) + dx_wk) / 14
    df_wk['adx'] = adx_wk.ewm(alpha = 1/14).mean() #ADX>20 is trending ADX<20 not trending
    
    df_wk['ADX_trend'] = 20
    
    
    
    if (df_wk['m_avg_08'][-1] > df_wk['m_avg_21'][-1] > df_wk['m_avg_34'][-1] > df_wk['m_avg_55'][-1] > df_wk['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Weekly stacked EMA\n is in the positive direction')
    elif (df_wk['m_avg_08'][-1] < df_wk['m_avg_21'][-1] < df_wk['m_avg_34'][-1] < df_wk['m_avg_55'][-1] < df_wk['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Weekly stacked EMA\n is in the negative direction')
    else:
        print (f'Ticker: {ticker}; Weekly stacked EMA\n is neutral')
        
    if (df_wk['adx'][-1] > df_wk['ADX_trend'][-1]) and (df_wk['plus_di'][-1] > df_wk['minus_di'][-1]):
        print (f'Ticker: {ticker}; Weekly directional trend is positive')
    elif (df_wk['adx'][-1] > df_wk['ADX_trend'][-1]) and (df_wk['plus_di'][-1] < df_wk['minus_di'][-1]):
        print (f'Ticker: {ticker}; Directional trend is negative')
    elif (df_wk['adx'][-1] < df_wk['ADX_trend'][-1]):
        print (f'Ticker: {ticker}; Directional trend is neutral or sideways')
    time.sleep(1)
# Out:
# Ticker: INMD; Weekly stacked EMA
#  is in the positive direction
# Ticker: INMD; Weekly directional trend is positive
# Ticker: ASAN; Weekly stacked EMA
#  is in the positive direction
# Ticker: ASAN; Weekly directional trend is positive
# Ticker: ATKR; Weekly stacked EMA
#  is in the positive direction
# Ticker: ATKR; Weekly directional trend is positive
# Ticker: SWAV; Weekly stacked EMA
#  is in the positive direction
# Ticker: SWAV; Weekly directional trend is positive
# Ticker: LSPD; Weekly stacked EMA
#  is neutral
# Ticker: LSPD; Directional trend is negative
# Ticker: CELH; Weekly stacked EMA
#  is in the positive direction
# Ticker: CELH; Weekly directional trend is positive
# Ticker: MRNA; Weekly stacked EMA
#  is neutral
# Ticker: MRNA; Directional trend is negative
# Ticker: BILL; Weekly stacked EMA
#  is in the positive direction
# Ticker: BILL; Weekly directional trend is positive
# Ticker: UPST; Weekly stacked EMA
#  is in the positive direction
# Ticker: UPST; Weekly directional trend is positive
# Ticker: TASK; Weekly stacked EMA
#  is in the positive direction
# Ticker: TASK; Weekly directional trend is positive
# Ticker: NET; Weekly stacked EMA
#  is in the positive direction
# Ticker: NET; Weekly directional trend is positive
# Ticker: SE; Weekly stacked EMA
#  is in the positive direction
# Ticker: SE; Directional trend is negative
# Ticker: DOCS; Weekly stacked EMA
#  is neutral
# Ticker: DOCS; Weekly directional trend is positive
# Ticker: ASML; Weekly stacked EMA
#  is in the positive direction
# Ticker: ASML; Weekly directional trend is positive
# Ticker: WAL; Weekly stacked EMA
#  is in the positive direction
# Ticker: WAL; Weekly directional trend is positive
# Ticker: GNRC; Weekly stacked EMA
#  is in the positive direction
# Ticker: GNRC; Weekly directional trend is positive
# Ticker: MDB; Weekly stacked EMA
#  is in the positive direction
# Ticker: MDB; Weekly directional trend is positive
# Ticker: GLBE; Weekly stacked EMA
#  is neutral
# Ticker: GLBE; Weekly directional trend is positive
# Ticker: DLO; Weekly stacked EMA
#  is neutral
# Ticker: DLO; Directional trend is negative
# Ticker: RGEN; Weekly stacked EMA
#  is in the positive direction
# Ticker: RGEN; Weekly directional trend is positive
# Ticker: PRFT; Weekly stacked EMA
#  is in the positive direction
# Ticker: PRFT; Weekly directional trend is positive
# Ticker: ZS; Weekly stacked EMA
#  is in the positive direction
# Ticker: ZS; Weekly directional trend is positive
# Ticker: AVTR; Weekly stacked EMA
#  is in the positive direction
# Ticker: AVTR; Weekly directional trend is positive
# Ticker: DDOG; Weekly stacked EMA
#  is in the positive direction
# Ticker: DDOG; Weekly directional trend is positive
# Ticker: SITM; Weekly stacked EMA
#  is in the positive direction
# Ticker: SITM; Weekly directional trend is positive
# Ticker: SPT; Weekly stacked EMA
#  is in the positive direction
# Ticker: SPT; Weekly directional trend is positive
# Ticker: MNDY; Weekly stacked EMA
#  is in the positive direction
# Ticker: MNDY; Weekly directional trend is positive
# Ticker: WST; Weekly stacked EMA
#  is in the positive direction
# Ticker: WST; Weekly directional trend is positive
# Ticker: NVDA; Weekly stacked EMA
#  is in the positive direction
# Ticker: NVDA; Weekly directional trend is positive
# Ticker: BX; Weekly stacked EMA
#  is in the positive direction
# Ticker: BX; Weekly directional trend is positive
# Ticker: HUBS; Weekly stacked EMA
#  is in the positive direction
# Ticker: HUBS; Weekly directional trend is positive
# Ticker: ZI; Weekly stacked EMA
#  is in the positive direction
# Ticker: ZI; Weekly directional trend is positive
# Ticker: JBL; Weekly stacked EMA
#  is in the positive direction
# Ticker: JBL; Directional trend is neutral or sideways
# Ticker: IT; Weekly stacked EMA
#  is in the positive direction
# Ticker: IT; Weekly directional trend is positive
# Ticker: ALGN; Weekly stacked EMA
#  is in the positive direction
# Ticker: ALGN; Weekly directional trend is positive
# Ticker: GOOGL; Weekly stacked EMA
#  is in the positive direction
# Ticker: GOOGL; Weekly directional trend is positive
# Ticker: MPWR; Weekly stacked EMA
#  is in the positive direction
# Ticker: MPWR; Weekly directional trend is positive
# Ticker: ARES; Weekly stacked EMA
#  is in the positive direction
# Ticker: ARES; Weekly directional trend is positive
# Ticker: IIPR; Weekly stacked EMA
#  is in the positive direction
# Ticker: IIPR; Weekly directional trend is positive
# Ticker: MATX; Weekly stacked EMA
#  is in the positive direction
# Ticker: MATX; Weekly directional trend is positive
# Ticker: KLIC; Weekly stacked EMA
#  is neutral
# Ticker: KLIC; Directional trend is neutral or sideways
# Ticker: BLDR; Weekly stacked EMA
#  is in the positive direction
# Ticker: BLDR; Weekly directional trend is positive
# Ticker: CROX; Weekly stacked EMA
#  is in the positive direction
# Ticker: CROX; Weekly directional trend is positive
# Ticker: JEF; Weekly stacked EMA
#  is in the positive direction
# Ticker: JEF; Weekly directional trend is positive
# Ticker: WSM; Weekly stacked EMA
#  is in the positive direction
# Ticker: WSM; Weekly directional trend is positive
# Ticker: AXNX; Weekly stacked EMA
#  is neutral
# Ticker: AXNX; Directional trend is neutral or sideways
# Ticker: RCII; Weekly stacked EMA
#  is neutral
# Ticker: RCII; Directional trend is negative
# Ticker: TPX; Weekly stacked EMA
#  is in the positive direction
# Ticker: TPX; Weekly directional trend is positive
# Ticker: CCS; Weekly stacked EMA
#  is in the positive direction
# Ticker: CCS; Directional trend is neutral or sideways
# Ticker: LULU; Weekly stacked EMA
#  is in the positive direction
# Ticker: LULU; Weekly directional trend is positive
# Ticker: NFLX; Weekly stacked EMA
#  is in the positive direction
# Ticker: NFLX; Weekly directional trend is positive
# Ticker: MA; Weekly stacked EMA
#  is neutral
# Ticker: MA; Directional trend is negative
# Ticker: ^DJI; Weekly stacked EMA
#  is in the positive direction
# Ticker: ^DJI; Directional trend is neutral or sideways
# Ticker: QQQ; Weekly stacked EMA
#  is in the positive direction
# Ticker: QQQ; Weekly directional trend is positive
# Ticker: SPY; Weekly stacked EMA
#  is in the positive direction
# Ticker: SPY; Weekly directional trend is positive
# Ticker: ES=F; Weekly stacked EMA
#  is in the positive direction
# Ticker: ES=F; Directional trend is neutral or sideways
# Ticker: YM=F; Weekly stacked EMA
#  is in the positive direction
# Ticker: YM=F; Directional trend is neutral or sideways
# Ticker: NQ=F; Weekly stacked EMA
#  is in the positive direction
# Ticker: NQ=F; Weekly directional trend is positive
# Ticker: ROKU; Weekly stacked EMA
#  is neutral
# Ticker: ROKU; Directional trend is neutral or sideways
# Ticker: WFC; Weekly stacked EMA
#  is in the positive direction
# Ticker: WFC; Directional trend is neutral or sideways
# Ticker: JD; Weekly stacked EMA
#  is in the positive direction
# Ticker: JD; Directional trend is neutral or sideways
# Ticker: AMC; Weekly stacked EMA
#  is in the positive direction
# Ticker: AMC; Weekly directional trend is positive
# Ticker: BA; Weekly stacked EMA
#  is in the negative direction
# Ticker: BA; Directional trend is neutral or sideways
# Ticker: TSLA; Weekly stacked EMA
#  is in the positive direction
# Ticker: TSLA; Weekly directional trend is positive
# Ticker: FB; Weekly stacked EMA
#  is in the positive direction
# Ticker: FB; Weekly directional trend is positive
# Ticker: AAPL; Weekly stacked EMA
#  is in the positive direction
# Ticker: AAPL; Weekly directional trend is positive
# Ticker: LOW; Weekly stacked EMA
#  is in the positive direction
# Ticker: LOW; Weekly directional trend is positive
# Ticker: AMZN; Weekly stacked EMA
#  is in the positive direction
# Ticker: AMZN; Directional trend is neutral or sideways

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df_mo = stock.history(period="10y", interval='1mo')
    df_mo.to_csv(f'{ticker}_mo.csv')    
    m_avg_mo = df_mo['Close'].ewm(span=length).mean()
    df_mo['Moving average'] = m_avg_mo
    # standard deviation
    m_std_mo = df_mo['Close'].rolling(window=length).std()
    # upper Bollinger Bands
    df_mo['upper_BB'] = m_avg_mo + mult * m_std_mo
    # lower Bollinger Bands 
    df_mo['lower_BB'] = m_avg_mo - mult * m_std_mo
    # calculate Keltner Channel which is a measure of the average true range.  In this case the channels are set to twice the average true range
    # first we need to calculate True Range
    df_mo['tr0'] = abs(df_mo["High"] - df_mo["Low"])
    df_mo['tr1'] = abs(df_mo["High"] - df_mo["Close"].shift())
    df_mo['tr2'] = abs(df_mo["Low"] - df_mo["Close"].shift())
    df_mo['tr'] = df_mo[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma_mo = df_mo['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df_mo['upper_KC'] = m_avg_mo + range_ma_mo * mult_KC
    # lower Keltner Channel
    df_mo['lower_KC'] = m_avg_mo - range_ma_mo * mult_KC
    
    df_mo['squeeze_on'] = (df_mo['lower_BB'] > df_mo['lower_KC']) & (df_mo['upper_BB'] < df_mo['upper_KC'])
    df_mo['squeeze_off'] = (df_mo['lower_BB'] < df_mo['lower_KC']) & (df_mo['upper_BB'] > df_mo['upper_KC'])
    
    highest_mo = df_mo['High'].rolling(window = length_KC).max()
    lowest_mo = df_mo['Low'].rolling(window = length_KC).min()
    m1_mo = (highest_mo + lowest_mo) / 2
    df_mo['value'] = (df_mo['Close'] - (m1_mo + m_avg_mo)/2)
    fit_y_mo = np.array(range(0,length_KC))
    df_mo['value'] = df_mo['value'].rolling(window = length_KC).apply(lambda x : np.polyfit(fit_y_mo, x, 1)[0] * (length_KC-1) +
    np.polyfit(fit_y_mo, x, 1)[1], raw=True)

    df_mo[['squeeze_on', 'squeeze_off']] = (df_mo[['squeeze_on', 'squeeze_off']] == True).astype(float)

    df_mo["pct_change"] = df_mo['Close'].pct_change()*100

    conditions_mo =  [
        (df_mo['pct_change'] > 0),
        (df_mo['pct_change'] < 0)
    ]

    label = [1, 0]
    df_mo['profitable?'] = np.select(conditions_mo, label) 
    
    # entry point for long position:
    # 1. black cross becomes gray (the squeeze is released)
    long_cond1_mo = (df_mo['squeeze_off'][-2] == 0) | (df_mo['squeeze_off'][-1] == 1) 
    # 2. bar value is positive => the bar is light green
    long_cond2_mo = df_mo['value'][-1] > 0

    enter_long_mo = long_cond1_mo and long_cond2_mo
    # entry point for short position:
    # 1. black cross becomes gray (the squeeze is released)
    short_cond1_mo = (df_mo['squeeze_off'][-2] == 0) | (df_mo['squeeze_off'][-1] == 1) 
    # 2. bar value is negative => the bar is light red 
    short_cond2_mo = df_mo['value'][-1] < 0
    enter_short_mo = short_cond1_mo and short_cond2_mo

    colors = []
    for ind, val in enumerate(df_mo['value']):
        if val >= 0:
            color = 'blue'
            if val > df_mo['value'][ind-1]:
                color = 'cyan'
                    
        else:
            color = 'yellow'
            if val < df_mo['value'][ind-1]:
                color='red'        
        colors.append(color)    
    df_mo['colors'] = colors
    color_value_mo = df_mo['colors'][-1]
    squeeze_value_mo = df_mo['squeeze_on'][-1]
    
    print (f'Ticker: {ticker}; monthly squeeze_scan\n {squeeze_value_mo},{color_value_mo}')
    time.sleep(1)
# Out:
# Ticker: INMD; monthly squeeze_scan
#  0.0,yellow
# Ticker: ASAN; monthly squeeze_scan
#  0.0,yellow
# Ticker: ATKR; monthly squeeze_scan
#  0.0,cyan
# Ticker: SWAV; monthly squeeze_scan
#  0.0,yellow
# Ticker: LSPD; monthly squeeze_scan
#  0.0,yellow
# Ticker: CELH; monthly squeeze_scan
#  0.0,blue
# Ticker: MRNA; monthly squeeze_scan
#  0.0,yellow
# Ticker: BILL; monthly squeeze_scan
#  0.0,yellow
# Ticker: UPST; monthly squeeze_scan
#  0.0,yellow
# Ticker: TASK; monthly squeeze_scan
#  0.0,yellow
# Ticker: NET; monthly squeeze_scan
#  0.0,yellow
# Ticker: SE; monthly squeeze_scan
#  0.0,blue
# Ticker: DOCS; monthly squeeze_scan
#  0.0,yellow
# Ticker: ASML; monthly squeeze_scan
#  0.0,yellow
# Ticker: WAL; monthly squeeze_scan
#  0.0,yellow
# Ticker: GNRC; monthly squeeze_scan
#  0.0,blue
# Ticker: MDB; monthly squeeze_scan
#  0.0,cyan
# Ticker: GLBE; monthly squeeze_scan
#  0.0,yellow
# Ticker: DLO; monthly squeeze_scan
#  0.0,yellow
# Ticker: RGEN; monthly squeeze_scan
#  0.0,blue
# Ticker: PRFT; monthly squeeze_scan
#  0.0,cyan
# Ticker: ZS; monthly squeeze_scan
#  0.0,cyan
# Ticker: AVTR; monthly squeeze_scan
#  0.0,yellow
# Ticker: DDOG; monthly squeeze_scan
#  0.0,yellow
# Ticker: SITM; monthly squeeze_scan
#  0.0,yellow
# Ticker: SPT; monthly squeeze_scan
#  0.0,yellow
# Ticker: MNDY; monthly squeeze_scan
#  0.0,yellow
# Ticker: WST; monthly squeeze_scan
#  0.0,yellow
# Ticker: NVDA; monthly squeeze_scan
#  0.0,yellow
# Ticker: BX; monthly squeeze_scan
#  0.0,yellow
# Ticker: HUBS; monthly squeeze_scan
#  0.0,cyan
# Ticker: ZI; monthly squeeze_scan
#  0.0,yellow
# Ticker: JBL; monthly squeeze_scan
#  0.0,yellow
# Ticker: IT; monthly squeeze_scan
#  0.0,cyan
# Ticker: ALGN; monthly squeeze_scan
#  0.0,blue
# Ticker: GOOGL; monthly squeeze_scan
#  0.0,cyan
# Ticker: MPWR; monthly squeeze_scan
#  0.0,yellow
# Ticker: ARES; monthly squeeze_scan
#  0.0,yellow
# Ticker: IIPR; monthly squeeze_scan
#  0.0,yellow
# Ticker: MATX; monthly squeeze_scan
#  0.0,yellow
# Ticker: KLIC; monthly squeeze_scan
#  0.0,yellow
# Ticker: BLDR; monthly squeeze_scan
#  0.0,cyan
# Ticker: CROX; monthly squeeze_scan
#  0.0,cyan
# Ticker: JEF; monthly squeeze_scan
#  0.0,yellow
# Ticker: WSM; monthly squeeze_scan
#  0.0,yellow
# Ticker: AXNX; monthly squeeze_scan
#  0.0,yellow
# Ticker: RCII; monthly squeeze_scan
#  0.0,yellow
# Ticker: TPX; monthly squeeze_scan
#  0.0,yellow
# Ticker: CCS; monthly squeeze_scan
#  0.0,yellow
# Ticker: LULU; monthly squeeze_scan
#  0.0,cyan
# Ticker: NFLX; monthly squeeze_scan
#  0.0,cyan
# Ticker: MA; monthly squeeze_scan
#  0.0,yellow
# Ticker: ^DJI; monthly squeeze_scan
#  0.0,blue
# Ticker: QQQ; monthly squeeze_scan
#  0.0,yellow
# Ticker: SPY; monthly squeeze_scan
#  0.0,yellow
# Ticker: ES=F; monthly squeeze_scan
#  0.0,cyan
# Ticker: YM=F; monthly squeeze_scan
#  0.0,cyan
# Ticker: NQ=F; monthly squeeze_scan
#  0.0,cyan
# Ticker: ROKU; monthly squeeze_scan
#  0.0,blue
# Ticker: WFC; monthly squeeze_scan
#  0.0,yellow
# Ticker: JD; monthly squeeze_scan
#  1.0,blue
# Ticker: AMC; monthly squeeze_scan
#  0.0,yellow
# Ticker: BA; monthly squeeze_scan
#  1.0,yellow
# Ticker: TSLA; monthly squeeze_scan
#  0.0,yellow
# Ticker: FB; monthly squeeze_scan
#  0.0,blue
# Ticker: AAPL; monthly squeeze_scan
#  0.0,yellow
# Ticker: LOW; monthly squeeze_scan
#  0.0,yellow
# Ticker: AMZN; monthly squeeze_scan
#  1.0,blue

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df_mo = stock.history(period="10y", interval='1mo')
    df_mo.to_csv(f'{ticker}_mo.csv')
    #Stacked Moving averages, exponentially weighted.  Focusing on Fibonacci numbers here with 8, 21, 34, 55 and 89 day moving averages
    m_avg_08_mo = df_mo['Close'].ewm(span=8).mean()
    m_avg_21_mo = df_mo['Close'].ewm(span=21).mean()
    m_avg_34_mo = df_mo['Close'].ewm(span=34).mean()
    m_avg_55_mo = df_mo['Close'].ewm(span=55).mean()
    m_avg_89_mo = df_mo['Close'].ewm(span=89).mean()

    df_mo['m_avg_08'] = m_avg_08_mo
    df_mo['m_avg_21'] = m_avg_21_mo
    df_mo['m_avg_34'] = m_avg_34_mo
    df_mo['m_avg_55'] = m_avg_55_mo
    df_mo['m_avg_89'] = m_avg_89_mo
    
    df_mo['tr0'] = abs(df_mo["High"] - df_mo["Low"])
    df_mo['tr1'] = abs(df_mo["High"] - df_mo["Close"].shift())
    df_mo['tr2'] = abs(df_mo["Low"] - df_mo["Close"].shift())
    df_mo['tr'] = df_mo[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma = df_mo['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df_mo['upper_KC'] = m_avg_mo + range_ma * mult_KC
    # lower Keltner Channel
    df_mo['lower_KC'] = m_avg_mo - range_ma * mult_KC
    
    plus_dm = df_mo["High"].diff()
    minus_dm = df_mo["Low"].diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    #plus_di and minus di show the direction of the trend, if plus_di > minus_di the trend is positive
    #if minus_di > plus_di the trend is negative
    df_mo['atr'] = df_mo['tr'].ewm(span=14).mean()
    df_mo['plus_di'] = 100 * (plus_dm.ewm(alpha = 1/14).mean() / df_mo['atr'])
    df_mo['minus_di'] = abs(100 * (minus_dm.ewm(alpha = 1/14).mean() / df_mo['atr']))
    dx_mo = (abs(df_mo['plus_di'] - df_mo['minus_di']) / abs(df_mo['plus_di'] + df_mo['minus_di'])) * 100
    adx_mo = ((dx_mo.shift(1) * (14 - 1)) + dx_mo) / 14
    df_mo['adx'] = adx_mo.ewm(alpha = 1/14).mean() #ADX>20 is trending ADX<20 not trending
    
    df_mo['ADX_trend'] = 20
    
    
    if (df_mo['m_avg_08'][-1] > df_mo['m_avg_21'][-1] > df_mo['m_avg_34'][-1] > df_mo['m_avg_55'][-1] > df_mo['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Monthly stacked EMA\n is in the positive direction')
    elif (df_mo['m_avg_08'][-1] < df_mo['m_avg_21'][-1] < df_mo['m_avg_34'][-1] < df_mo['m_avg_55'][-1] < df_mo['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Monthly stacked EMA\n is in the negative direction')
    else:
        print (f'Ticker: {ticker}; Weekly stacked EMA\n is neutral')
        
    if (df_mo['adx'][-1] > df_mo['ADX_trend'][-1]) and (df_mo['plus_di'][-1] > df_mo['minus_di'][-1]):
        print (f'Ticker: {ticker}; Monthly directional trend is positive')
    elif (df_mo['adx'][-1] > df_mo['ADX_trend'][-1]) and (df_mo['plus_di'][-1] < df_mo['minus_di'][-1]):
        print (f'Ticker: {ticker}; Monthly directional trend is negative')
    elif (df_mo['adx'][-1] < df_mo['ADX_trend'][-1]):
        print (f'Ticker: {ticker}; Monthly directional trend is neutral or sideways')
    time.sleep(1)
# Out:
# Ticker: INMD; Monthly stacked EMA
#  is in the positive direction
# Ticker: INMD; Monthly directional trend is positive
# Ticker: ASAN; Monthly stacked EMA
#  is in the positive direction
# Ticker: ASAN; Monthly directional trend is positive
# Ticker: ATKR; Monthly stacked EMA
#  is in the positive direction
# Ticker: ATKR; Monthly directional trend is positive
# Ticker: SWAV; Monthly stacked EMA
#  is in the positive direction
# Ticker: SWAV; Monthly directional trend is positive
# Ticker: LSPD; Monthly stacked EMA
#  is in the positive direction
# Ticker: LSPD; Monthly directional trend is positive
# Ticker: CELH; Monthly stacked EMA
#  is in the positive direction
# Ticker: CELH; Monthly directional trend is positive
# Ticker: MRNA; Monthly stacked EMA
#  is in the positive direction
# Ticker: MRNA; Monthly directional trend is positive
# Ticker: BILL; Monthly stacked EMA
#  is in the positive direction
# Ticker: BILL; Monthly directional trend is positive
# Ticker: UPST; Monthly stacked EMA
#  is in the positive direction
# Ticker: UPST; Monthly directional trend is positive
# Ticker: TASK; Monthly stacked EMA
#  is in the positive direction
# Ticker: TASK; Monthly directional trend is positive
# Ticker: NET; Monthly stacked EMA
#  is in the positive direction
# Ticker: NET; Monthly directional trend is positive
# Ticker: SE; Monthly stacked EMA
#  is in the positive direction
# Ticker: SE; Monthly directional trend is positive
# Ticker: DOCS; Monthly stacked EMA
#  is in the negative direction
# Ticker: DOCS; Monthly directional trend is positive
# Ticker: ASML; Monthly stacked EMA
#  is in the positive direction
# Ticker: ASML; Monthly directional trend is positive
# Ticker: WAL; Monthly stacked EMA
#  is in the positive direction
# Ticker: WAL; Monthly directional trend is positive
# Ticker: GNRC; Monthly stacked EMA
#  is in the positive direction
# Ticker: GNRC; Monthly directional trend is positive
# Ticker: MDB; Monthly stacked EMA
#  is in the positive direction
# Ticker: MDB; Monthly directional trend is positive
# Ticker: GLBE; Monthly stacked EMA
#  is in the negative direction
# Ticker: GLBE; Monthly directional trend is positive
# Ticker: DLO; Monthly stacked EMA
#  is in the negative direction
# Ticker: DLO; Monthly directional trend is negative
# Ticker: RGEN; Monthly stacked EMA
#  is in the positive direction
# Ticker: RGEN; Monthly directional trend is positive
# Ticker: PRFT; Monthly stacked EMA
#  is in the positive direction
# Ticker: PRFT; Monthly directional trend is positive
# Ticker: ZS; Monthly stacked EMA
#  is in the positive direction
# Ticker: ZS; Monthly directional trend is positive
# Ticker: AVTR; Monthly stacked EMA
#  is in the positive direction
# Ticker: AVTR; Monthly directional trend is positive
# Ticker: DDOG; Monthly stacked EMA
#  is in the positive direction
# Ticker: DDOG; Monthly directional trend is positive
# Ticker: SITM; Monthly stacked EMA
#  is in the positive direction
# Ticker: SITM; Monthly directional trend is positive
# Ticker: SPT; Monthly stacked EMA
#  is in the positive direction
# Ticker: SPT; Monthly directional trend is positive
# Ticker: MNDY; Monthly stacked EMA
#  is in the positive direction
# Ticker: MNDY; Monthly directional trend is positive
# Ticker: WST; Monthly stacked EMA
#  is in the positive direction
# Ticker: WST; Monthly directional trend is positive
# Ticker: NVDA; Monthly stacked EMA
#  is in the positive direction
# Ticker: NVDA; Monthly directional trend is positive
# Ticker: BX; Monthly stacked EMA
#  is in the positive direction
# Ticker: BX; Monthly directional trend is positive
# Ticker: HUBS; Monthly stacked EMA
#  is in the positive direction
# Ticker: HUBS; Monthly directional trend is positive
# Ticker: ZI; Monthly stacked EMA
#  is in the positive direction
# Ticker: ZI; Monthly directional trend is positive
# Ticker: JBL; Monthly stacked EMA
#  is in the positive direction
# Ticker: JBL; Monthly directional trend is positive
# Ticker: IT; Monthly stacked EMA
#  is in the positive direction
# Ticker: IT; Monthly directional trend is positive
# Ticker: ALGN; Monthly stacked EMA
#  is in the positive direction
# Ticker: ALGN; Monthly directional trend is positive
# Ticker: GOOGL; Monthly stacked EMA
#  is in the positive direction
# Ticker: GOOGL; Monthly directional trend is positive
# Ticker: MPWR; Monthly stacked EMA
#  is in the positive direction
# Ticker: MPWR; Monthly directional trend is positive
# Ticker: ARES; Monthly stacked EMA
#  is in the positive direction
# Ticker: ARES; Monthly directional trend is positive
# Ticker: IIPR; Monthly stacked EMA
#  is in the positive direction
# Ticker: IIPR; Monthly directional trend is positive
# Ticker: MATX; Monthly stacked EMA
#  is in the positive direction
# Ticker: MATX; Monthly directional trend is positive
# Ticker: KLIC; Monthly stacked EMA
#  is in the positive direction
# Ticker: KLIC; Monthly directional trend is positive
# Ticker: BLDR; Monthly stacked EMA
#  is in the positive direction
# Ticker: BLDR; Monthly directional trend is positive
# Ticker: CROX; Monthly stacked EMA
#  is in the positive direction
# Ticker: CROX; Monthly directional trend is positive
# Ticker: JEF; Monthly stacked EMA
#  is in the positive direction
# Ticker: JEF; Monthly directional trend is positive
# Ticker: WSM; Monthly stacked EMA
#  is in the positive direction
# Ticker: WSM; Monthly directional trend is positive
# Ticker: AXNX; Monthly stacked EMA
#  is in the positive direction
# Ticker: AXNX; Monthly directional trend is positive
# Ticker: RCII; Monthly stacked EMA
#  is in the positive direction
# Ticker: RCII; Monthly directional trend is positive
# Ticker: TPX; Monthly stacked EMA
#  is in the positive direction
# Ticker: TPX; Monthly directional trend is positive
# Ticker: CCS; Monthly stacked EMA
#  is in the positive direction
# Ticker: CCS; Monthly directional trend is positive
# Ticker: LULU; Monthly stacked EMA
#  is in the positive direction
# Ticker: LULU; Monthly directional trend is positive
# Ticker: NFLX; Monthly stacked EMA
#  is in the positive direction
# Ticker: NFLX; Monthly directional trend is positive
# Ticker: MA; Monthly stacked EMA
#  is in the positive direction
# Ticker: MA; Monthly directional trend is neutral or sideways
# Ticker: ^DJI; Monthly stacked EMA
#  is in the positive direction
# Ticker: ^DJI; Monthly directional trend is positive
# Ticker: QQQ; Monthly stacked EMA
#  is in the positive direction
# Ticker: QQQ; Monthly directional trend is positive
# Ticker: SPY; Monthly stacked EMA
#  is in the positive direction
# Ticker: SPY; Monthly directional trend is positive
# Ticker: ES=F; Monthly stacked EMA
#  is in the positive direction
# Ticker: ES=F; Monthly directional trend is positive
# Ticker: YM=F; Monthly stacked EMA
#  is in the positive direction
# Ticker: YM=F; Monthly directional trend is positive
# Ticker: NQ=F; Monthly stacked EMA
#  is in the positive direction
# Ticker: NQ=F; Monthly directional trend is positive
# Ticker: ROKU; Monthly stacked EMA
#  is in the positive direction
# Ticker: ROKU; Monthly directional trend is positive
# Ticker: WFC; Weekly stacked EMA
#  is neutral
# Ticker: WFC; Monthly directional trend is positive
# Ticker: JD; Monthly stacked EMA
#  is in the positive direction
# Ticker: JD; Monthly directional trend is positive
# Ticker: AMC; Monthly stacked EMA
#  is in the positive direction
# Ticker: AMC; Monthly directional trend is positive
# Ticker: BA; Weekly stacked EMA
#  is neutral
# Ticker: BA; Monthly directional trend is positive
# Ticker: TSLA; Monthly stacked EMA
#  is in the positive direction
# Ticker: TSLA; Monthly directional trend is positive
# Ticker: FB; Monthly stacked EMA
#  is in the positive direction
# Ticker: FB; Monthly directional trend is positive
# Ticker: AAPL; Monthly stacked EMA
#  is in the positive direction
# Ticker: AAPL; Monthly directional trend is positive
# Ticker: LOW; Monthly stacked EMA
#  is in the positive direction
# Ticker: LOW; Monthly directional trend is positive
# Ticker: AMZN; Monthly stacked EMA
#  is in the positive direction
# Ticker: AMZN; Monthly directional trend is positive

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df_hr = stock.history(period="3mo", interval='1h')
    df_hr.to_csv(f'{ticker}_hr.csv')    
    m_avg_hr = df_hr['Close'].ewm(span=length).mean()
    df_hr['Moving average'] = m_avg_hr
    # standard deviation
    m_std_hr = df_hr['Close'].rolling(window=length).std()
    # upper Bollinger Bands
    df_hr['upper_BB'] = m_avg_hr + mult * m_std_hr
    # lower Bollinger Bands 
    df_hr['lower_BB'] = m_avg_hr - mult * m_std_hr
    # calculate Keltner Channel which is a measure of the average true range.  In this case the channels are set to twice the average true range
    # first we need to calculate True Range
    df_hr['tr0'] = abs(df_hr["High"] - df_hr["Low"])
    df_hr['tr1'] = abs(df_hr["High"] - df_hr["Close"].shift())
    df_hr['tr2'] = abs(df_hr["Low"] - df_hr["Close"].shift())
    df_hr['tr'] = df_hr[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma_hr = df_hr['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df_hr['upper_KC'] = m_avg_hr + range_ma_hr * mult_KC
    # lower Keltner Channel
    df_hr['lower_KC'] = m_avg_hr - range_ma_hr * mult_KC
    
    df_hr['squeeze_on'] = (df_hr['lower_BB'] > df_hr['lower_KC']) & (df_hr['upper_BB'] < df_hr['upper_KC'])
    df_hr['squeeze_off'] = (df_hr['lower_BB'] < df_hr['lower_KC']) & (df_hr['upper_BB'] > df_hr['upper_KC'])
    
    highest_hr = df_hr['High'].rolling(window = length_KC).max()
    lowest_hr = df_hr['Low'].rolling(window = length_KC).min()
    m1_hr = (highest_hr + lowest_hr) / 2
    df_hr['value'] = (df_hr['Close'] - (m1_hr + m_avg_hr)/2)
    fit_y_hr = np.array(range(0,length_KC))
    df_hr['value'] = df_hr['value'].rolling(window = length_KC).apply(lambda x : np.polyfit(fit_y_hr, x, 1)[0] * (length_KC-1) +
    np.polyfit(fit_y_hr, x, 1)[1], raw=True)

    df_hr[['squeeze_on', 'squeeze_off']] = (df_hr[['squeeze_on', 'squeeze_off']] == True).astype(float)

    df_hr["pct_change"] = df_hr['Close'].pct_change()*100

    conditions_hr =  [
        (df_hr['pct_change'] > 0),
        (df_hr['pct_change'] < 0)
    ]

    label = [1, 0]
    df_hr['profitable?'] = np.select(conditions_hr, label) 
    
    # entry point for long position:
    # 1. black cross becomes gray (the squeeze is released)
    long_cond1_hr = (df_hr['squeeze_off'][-2] == 0) | (df_hr['squeeze_off'][-1] == 1) 
    # 2. bar value is positive => the bar is light green
    long_cond2_hr = df_hr['value'][-1] > 0

    enter_long_hr = long_cond1_hr and long_cond2_hr
    # entry point for short position:
    # 1. black cross becomes gray (the squeeze is released)
    short_cond1_hr = (df_hr['squeeze_off'][-2] == 0) | (df_hr['squeeze_off'][-1] == 1) 
    # 2. bar value is negative => the bar is light red 
    short_cond2_hr = df_hr['value'][-1] < 0
    enter_short_hr = short_cond1_hr and short_cond2_hr

    colors = []
    for ind, val in enumerate(df_hr['value']):
        if val >= 0:
            color = 'blue'
            if val > df_hr['value'][ind-1]:
                color = 'cyan'
                    
        else:
            color = 'yellow'
            if val < df_hr['value'][ind-1]:
                color='red'        
        colors.append(color)    
    df_hr['colors'] = colors
    color_value_hr = df_hr['colors'][-1]
    squeeze_value_hr = df_hr['squeeze_on'][-1]
    
    print (f'Ticker: {ticker}; hourly squeeze_scan\n {squeeze_value_hr},{color_value_hr}')
    time.sleep(1)
# Out:
# Ticker: INMD; hourly squeeze_scan
#  1.0,yellow
# Ticker: ASAN; hourly squeeze_scan
#  0.0,blue
# Ticker: ATKR; hourly squeeze_scan
#  0.0,red
# Ticker: SWAV; hourly squeeze_scan
#  0.0,blue
# Ticker: LSPD; hourly squeeze_scan
#  0.0,red
# Ticker: CELH; hourly squeeze_scan
#  1.0,yellow
# Ticker: MRNA; hourly squeeze_scan
#  0.0,red
# Ticker: BILL; hourly squeeze_scan
#  0.0,blue
# Ticker: UPST; hourly squeeze_scan
#  0.0,red
# Ticker: TASK; hourly squeeze_scan
#  0.0,red
# Ticker: NET; hourly squeeze_scan
#  0.0,blue
# Ticker: SE; hourly squeeze_scan
#  0.0,yellow
# Ticker: DOCS; hourly squeeze_scan
#  0.0,red
# Ticker: ASML; hourly squeeze_scan
#  0.0,cyan
# Ticker: WAL; hourly squeeze_scan
#  0.0,cyan
# Ticker: GNRC; hourly squeeze_scan
#  0.0,cyan
# Ticker: MDB; hourly squeeze_scan
#  1.0,red
# Ticker: GLBE; hourly squeeze_scan
#  0.0,red
# Ticker: DLO; hourly squeeze_scan
#  0.0,yellow
# Ticker: RGEN; hourly squeeze_scan
#  1.0,cyan
# Ticker: PRFT; hourly squeeze_scan
#  0.0,yellow
# Ticker: ZS; hourly squeeze_scan
#  0.0,cyan
# Ticker: AVTR; hourly squeeze_scan
#  1.0,red
# Ticker: DDOG; hourly squeeze_scan
#  0.0,cyan
# Ticker: SITM; hourly squeeze_scan
#  1.0,cyan
# Ticker: SPT; hourly squeeze_scan
#  1.0,yellow
# Ticker: MNDY; hourly squeeze_scan
#  1.0,cyan
# Ticker: WST; hourly squeeze_scan
#  0.0,blue
# Ticker: NVDA; hourly squeeze_scan
#  0.0,blue
# Ticker: BX; hourly squeeze_scan
#  0.0,cyan
# Ticker: HUBS; hourly squeeze_scan
#  1.0,cyan
# Ticker: ZI; hourly squeeze_scan
#  1.0,cyan
# Ticker: JBL; hourly squeeze_scan
#  0.0,blue
# Ticker: IT; hourly squeeze_scan
#  0.0,cyan
# Ticker: ALGN; hourly squeeze_scan
#  0.0,red
# Ticker: GOOGL; hourly squeeze_scan
#  0.0,yellow
# Ticker: MPWR; hourly squeeze_scan
#  0.0,blue
# Ticker: ARES; hourly squeeze_scan
#  0.0,blue
# Ticker: IIPR; hourly squeeze_scan
#  0.0,blue
# Ticker: MATX; hourly squeeze_scan
#  0.0,cyan
# Ticker: KLIC; hourly squeeze_scan
#  0.0,blue
# Ticker: BLDR; hourly squeeze_scan
#  1.0,blue
# Ticker: CROX; hourly squeeze_scan
#  0.0,cyan
# Ticker: JEF; hourly squeeze_scan
#  0.0,cyan
# Ticker: WSM; hourly squeeze_scan
#  1.0,blue
# Ticker: AXNX; hourly squeeze_scan
#  1.0,blue
# Ticker: RCII; hourly squeeze_scan
#  0.0,blue
# Ticker: TPX; hourly squeeze_scan
#  0.0,blue
# Ticker: CCS; hourly squeeze_scan
#  1.0,blue
# Ticker: LULU; hourly squeeze_scan
#  0.0,blue
# Ticker: NFLX; hourly squeeze_scan
#  0.0,cyan
# Ticker: MA; hourly squeeze_scan
#  1.0,cyan
# Ticker: ^DJI; hourly squeeze_scan
#  1.0,blue
# Ticker: QQQ; hourly squeeze_scan
#  1.0,red
# Ticker: SPY; hourly squeeze_scan
#  1.0,blue
# Ticker: ES=F; hourly squeeze_scan
#  1.0,red
# Ticker: YM=F; hourly squeeze_scan
#  1.0,blue
# Ticker: NQ=F; hourly squeeze_scan
#  1.0,red
# Ticker: ROKU; hourly squeeze_scan
#  0.0,red
# Ticker: WFC; hourly squeeze_scan
#  1.0,cyan
# Ticker: JD; hourly squeeze_scan
#  0.0,red
# Ticker: AMC; hourly squeeze_scan
#  0.0,red
# Ticker: BA; hourly squeeze_scan
#  0.0,red
# Ticker: TSLA; hourly squeeze_scan
#  0.0,cyan
# Ticker: FB; hourly squeeze_scan
#  0.0,red
# Ticker: AAPL; hourly squeeze_scan
#  1.0,red
# Ticker: LOW; hourly squeeze_scan
#  0.0,blue
# Ticker: AMZN; hourly squeeze_scan
#  0.0,red

# %%
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    stock = yf.Ticker(ticker)
    df_mo = stock.history(period="10y", interval='1mo')
    df_mo.to_csv(f'{ticker}_mo.csv')
    #Stacked Moving averages, exponentially weighted.  Focusing on Fibonacci numbers here with 8, 21, 34, 55 and 89 day moving averages
    m_avg_08_mo = df_mo['Close'].ewm(span=8).mean()
    m_avg_21_mo = df_mo['Close'].ewm(span=21).mean()
    m_avg_34_mo = df_mo['Close'].ewm(span=34).mean()
    m_avg_55_mo = df_mo['Close'].ewm(span=55).mean()
    m_avg_89_mo = df_mo['Close'].ewm(span=89).mean()

    df_mo['m_avg_08'] = m_avg_08_mo
    df_mo['m_avg_21'] = m_avg_21_mo
    df_mo['m_avg_34'] = m_avg_34_mo
    df_mo['m_avg_55'] = m_avg_55_mo
    df_mo['m_avg_89'] = m_avg_89_mo
    
    df_mo['tr0'] = abs(df_mo["High"] - df_mo["Low"])
    df_mo['tr1'] = abs(df_mo["High"] - df_mo["Close"].shift())
    df_mo['tr2'] = abs(df_mo["Low"] - df_mo["Close"].shift())
    df_mo['tr'] = df_mo[['tr0', 'tr1', 'tr2']].max(axis=1)
    # moving average of the TR or average true range
    range_ma = df_mo['tr'].ewm(span=length_KC).mean()
    # upper Keltner Channel
    df_mo['upper_KC'] = m_avg_mo + range_ma * mult_KC
    # lower Keltner Channel
    df_mo['lower_KC'] = m_avg_mo - range_ma * mult_KC
    
    plus_dm = df_mo["High"].diff()
    minus_dm = df_mo["Low"].diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    #plus_di and minus di show the direction of the trend, if plus_di > minus_di the trend is positive
    #if minus_di > plus_di the trend is negative
    df_mo['atr'] = df_mo['tr'].ewm(span=14).mean()
    df_mo['plus_di'] = 100 * (plus_dm.ewm(alpha = 1/14).mean() / df_mo['atr'])
    df_mo['minus_di'] = abs(100 * (minus_dm.ewm(alpha = 1/14).mean() / df_mo['atr']))
    dx_mo = (abs(df_mo['plus_di'] - df_mo['minus_di']) / abs(df_mo['plus_di'] + df_mo['minus_di'])) * 100
    adx_mo = ((dx_mo.shift(1) * (14 - 1)) + dx_mo) / 14
    df_mo['adx'] = adx_mo.ewm(alpha = 1/14).mean() #ADX>20 is trending ADX<20 not trending
    
    df_mo['ADX_trend'] = 20
    
    
    if (df_mo['m_avg_08'][-1] > df_mo['m_avg_21'][-1] > df_mo['m_avg_34'][-1] > df_mo['m_avg_55'][-1] > df_mo['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Monthly stacked EMA\n is in the positive direction')
    elif (df_mo['m_avg_08'][-1] < df_mo['m_avg_21'][-1] < df_mo['m_avg_34'][-1] < df_mo['m_avg_55'][-1] < df_mo['m_avg_89'][-1]):
        print (f'Ticker: {ticker}; Monthly stacked EMA\n is in the negative direction')
    else:
        print (f'Ticker: {ticker}; Weekly stacked EMA\n is neutral')
        
    if (df_mo['adx'][-1] > df_mo['ADX_trend'][-1]) and (df_mo['plus_di'][-1] > df_mo['minus_di'][-1]):
        print (f'Ticker: {ticker}; Monthly directional trend is positive')
    elif (df_mo['adx'][-1] > df_mo['ADX_trend'][-1]) and (df_mo['plus_di'][-1] < df_mo['minus_di'][-1]):
        print (f'Ticker: {ticker}; Monthly directional trend is negative')
    elif (df_mo['adx'][-1] < df_mo['ADX_trend'][-1]):
        print (f'Ticker: {ticker}; Monthly directional trend is neutral or sideways')
    time.sleep(1)
